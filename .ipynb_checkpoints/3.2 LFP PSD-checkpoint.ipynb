# %%
import warnings
warnings.filterwarnings("ignore")

# Import public packages and functions
import os
import pandas as pd
import numpy as np
import sys
import json
from pathlib import Path

import seaborn as sns
import matplotlib.pyplot as plt
import scikit_posthocs as sp

# inserting the lib folder to the compiler
sys.path.insert(0, './lib')
sys.path.insert(0, './utils/')

#import utils scripts
import utils_accelerometer, utils_misc, utils_psd, utils_plotting_psd

from lib_LFP import LFP
from lib_event import EVENTS
from lib_data import DATA_IO

# %% [markdown]
# # 1. Data Load

# %%
PATH_CURR  = os.path.abspath(os.curdir)    # current code
PATH       = (str(Path(PATH_CURR).parent)) # data repository: upper directory where datasets situated
SUB        = '016'

# 1. Load event history of patient
df_lfp_events = pd.read_pickle(DATA_IO.path_events_dataframe + "SUB_"+ SUB +"_EVENTS_LFP_RECORDINGS.pkl")
df_lfp_events.LFP_channel = df_lfp_events.LFP_channel.apply(str)

# %% [markdown]
# # 2. Normalized PSD Plots

# %% [markdown]
# ## 2.1 Average PSD for Event Segment without Hemisphere Separation

# %% [markdown]
# ### 2.1.1 Involuntary Movements

# %%
utils_plotting_psd.plot_LFP_PSD_for_event_category(df_lfp_events, event_category="involuntary_movement", segment="event")
# Out:
# PRE-EVENT SEGMENT ----------------------------------------------------------------------------------
# EVENT SEGMENT --------------------------------------------------------------------------------------
# POST-EVENT SEGMENT ---------------------------------------------------------------------------------

# %% [markdown]
# # 2.1.2 Tapping

# %%
utils_plotting_psd.plot_LFP_PSD_for_event_category_and_segment(df_lfp_events, event_category="tapping")

# %%
print("PRE-EVENT SEGMENT ----------------------------------------------------------------------------------")
utils_plotting_psd.plot_LFP_PSD_for_event_category(df_lfp_events, event_category="tapping", segment="pre_event")
print("EVENT SEGMENT --------------------------------------------------------------------------------------")
utils_plotting_psd.plot_LFP_PSD_for_event_category(df_lfp_events, event_category="tapping", segment="event")
print("POST-EVENT SEGMENT ---------------------------------------------------------------------------------")
utils_plotting_psd.plot_LFP_PSD_for_event_category(df_lfp_events, event_category="tapping", segment="post_event")
# Out:
# PRE-EVENT SEGMENT ----------------------------------------------------------------------------------
# EVENT SEGMENT --------------------------------------------------------------------------------------
# POST-EVENT SEGMENT ---------------------------------------------------------------------------------

# %%
utils_plotting_psd.plot_LFP_PSD_for_event_category(utils_plotting_psd.plot_LFP_PSD_for_event_category(df_lfp_events, event_category="involuntary_movement", segment="event"), event_category="involuntary_movement", segment="pre_event")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 utils_plotting_psd.plot_LFP_PSD_for_event_category(utils_plotting_psd.plot_LFP_PSD_for_event_category(df_lfp_events, event_category="involuntary_movement", segment="event"), event_category="involuntary_movement", segment="pre_event")
#
# File ~\Desktop\Papers\2025 Parkinson Dyskinesia LFP-ECG\files\PD-Dyskinesia-Electrophysiology\./utils\utils_plotting_psd.py:198, in plot_LFP_PSD_for_event_category(dataset, event_category, segment)
#     196 channel = "32"
#     197 for severity in ["none","mild","moderate","severe","extreme"]:
# --> 198     freq_i, mean_i, error_i, freq_c, mean_c, error_c = LFP.measure_LFP_power_spectra_with_laterality(dataset, "", channel, event_category, segment, severity)
# ...

# %%
utils_plotting_psd.plot_LFP_PSD_for_event_category(df_lfp_events, event_category="tapping", segment="event")

# %%
utils_plotting_psd.plot_LFP_PSD_for_event_category(df_lfp_events, event_category="tapping", segment="pre_event")

# %%
plot_LFP_PSD_for_hemisphere_and_even_category(df_lfp_events, hemisphere="left", 
                                              event_category="involuntary_movement", 
                                              segment="event")

# %%
plot_LFP_PSD_for_hemisphere_and_even_category(df_lfp_events, hemisphere="left", 
                                              event_category="involuntary_movement", 
                                              segment="pre_event")

# %%
plot_LFP_PSD_for_hemisphere_and_even_category(df_lfp_events, hemisphere="left", 
                                              event_category="involuntary_movement", 
                                              segment="post_event")
