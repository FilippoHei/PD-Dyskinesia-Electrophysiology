# %%
# Import public packages and functions
import os
import pandas as pd
import numpy as np
import sys
import json
from pathlib import Path

import seaborn as sns
import matplotlib.pyplot as plt
import scikit_posthocs as sp

import warnings
warnings.filterwarnings("ignore")

# inserting the lib folder to the compiler
sys.path.insert(0, './lib')
sys.path.insert(0, './utils/')

import utils_misc, utils_io, utils_plotting, utils_mutual_information, utils_statistics, utils_spectrogram, utils_plotting_spectrogram
from lib_data import DATA_IO

# %%
fs                      = 2048
PATH_CURR               = os.path.abspath(os.curdir)    # current code
PATH                    = (str(Path(PATH_CURR).parent)) # data repository: upper directory where datasets situated
df_TAPPING_MOTOR_events = pd.read_pickle(DATA_IO.path_events + "LFP_TAPPING_EVENTS_MOTOR_AREA.pkl")
df_TAPPING_MOTOR_events = df_TAPPING_MOTOR_events[df_TAPPING_MOTOR_events.patient != "019"]

df_controlateral        = df_TAPPING_MOTOR_events[df_TAPPING_MOTOR_events.event_laterality != df_TAPPING_MOTOR_events.LFP_hemisphere]
df_controlateral        = utils_misc.get_onset_and_offset_aligned_recordings(df_controlateral, fs=fs)
df_controlateral        = df_controlateral[["patient", "LFP_hemisphere", "LFP_channel", "recording_onset_aligned","recording_offset_aligned","dyskinesia_arm"]]
df_controlateral.reset_index(inplace=True, drop=True)

baseline_recordings     = utils_io.load_baseline_recordings(recording_type="LFP")

# %% [markdown]
# # 1. Calculate Channel and Severity-Wise Time-Frequency Activity

# %%
dataset               = pd.DataFrame(df_controlateral)
dataset["hemisphere"] = dataset.LFP_hemisphere
dataset["channel"]    = dataset.LFP_channel
dataset.reset_index(inplace=True, drop=True)

df_spectrogram        = utils_spectrogram.measure_normalized_multitaper_spectrograms(dataset, fs, baseline_recordings)
df_spectrogram.to_pickle(DATA_IO.path_events + "time_frequency_activity/LFP_TFA")
# Out:
# patient 008 - left - 04-01 - mild
# patient 008 - left - 04-01 - moderate
# patient 008 - left - 05-02 - mild
# patient 008 - left - 05-02 - moderate
# patient 008 - left - 06-03 - mild
# patient 008 - left - 06-03 - moderate
# patient 008 - left - 07-04 - mild
# patient 008 - left - 07-04 - moderate
# patient 008 - left - 08-05 - mild
# patient 008 - left - 08-05 - moderate
# patient 008 - left - 09-06 - mild
# patient 008 - left - 09-06 - moderate
# patient 008 - left - 10-07 - mild
# patient 008 - left - 10-07 - moderate
# patient 008 - left - 11-08 - mild
# patient 008 - left - 11-08 - moderate
# patient 008 - left - 11-09 - mild
# patient 008 - left - 11-09 - moderate
# patient 008 - left - 13-10 - mild
# patient 008 - left - 13-10 - moderate
# patient 008 - left - 14-11 - mild
# patient 008 - left - 14-11 - moderate
# patient 008 - right - 11-09 - mild
# patient 008 - right - 04-01 - mild
# patient 008 - right - 05-02 - mild
# patient 008 - right - 06-03 - mild
# patient 008 - right - 07-04 - mild
# patient 008 - right - 08-05 - mild
# patient 008 - right - 09-06 - mild
# patient 008 - right - 10-07 - mild
# patient 009 - left - 02-01 - none
# patient 009 - left - 02-01 - mild
# patient 009 - left - 03-01 - none
# patient 009 - left - 03-01 - mild
# patient 009 - left - 04-01 - none
# patient 009 - left - 04-01 - mild
# patient 009 - left - 06-03 - none
# patient 009 - left - 06-03 - mild
# patient 009 - left - 08-06 - none
# patient 009 - left - 08-06 - mild
# patient 009 - right - 07-04 - none
# patient 009 - right - 07-04 - mild
# patient 012 - left - 05-02 - mild
# patient 012 - left - 05-02 - moderate
# patient 012 - left - 08-05 - mild
# patient 012 - left - 08-05 - moderate
# patient 012 - left - 08-06 - mild
# patient 012 - left - 08-06 - moderate
# patient 012 - left - 08-07 - mild
# patient 012 - left - 08-07 - moderate
# patient 012 - left - 06-03 - mild
# patient 012 - left - 06-03 - moderate
# patient 012 - left - 07-04 - mild
# patient 012 - left - 07-04 - moderate
# patient 012 - right - 02-01 - mild
# patient 012 - right - 02-01 - moderate
# patient 012 - right - 03-01 - mild
# patient 012 - right - 03-01 - moderate
# patient 012 - right - 04-01 - mild
# patient 012 - right - 04-01 - moderate
# patient 012 - right - 05-02 - mild
# patient 012 - right - 05-02 - moderate
# patient 013 - left - 05-02 - none
# patient 013 - left - 05-02 - mild
# patient 013 - left - 07-04 - none
# patient 013 - left - 08-05 - none
# patient 013 - left - 08-05 - mild
# patient 013 - left - 08-07 - none
# patient 013 - left - 08-07 - mild
# patient 013 - left - 06-03 - none
# patient 013 - left - 06-03 - mild
# patient 013 - left - 08-06 - none
# patient 013 - left - 08-06 - mild
# patient 013 - right - 02-01 - none
# patient 013 - right - 03-01 - none
# patient 013 - right - 04-01 - none
# patient 013 - right - 07-04 - none
# patient 013 - right - 08-07 - none
# patient 014 - left - 08-05 - none
# patient 014 - left - 08-05 - mild
# patient 014 - left - 08-06 - none
# patient 014 - left - 08-06 - mild
# patient 014 - left - 05-02 - none
# patient 014 - left - 05-02 - mild
# patient 014 - left - 06-03 - none
# patient 014 - left - 06-03 - mild
# patient 014 - left - 07-04 - none
# patient 014 - left - 07-04 - mild
# patient 014 - left - 08-07 - none
# patient 014 - left - 08-07 - mild
# patient 014 - right - 02-01 - none
# patient 014 - right - 03-01 - none
# patient 014 - right - 04-01 - none
# patient 014 - right - 05-02 - none
# patient 020 - left - 06-03 - moderate
# patient 020 - left - 06-03 - mild
# patient 020 - left - 07-04 - moderate
# patient 020 - left - 07-04 - mild
# patient 020 - left - 08-06 - moderate
# patient 020 - left - 08-06 - mild
# patient 020 - left - 08-07 - moderate
# patient 020 - left - 08-07 - mild
# patient 020 - right - 03-01 - none
# patient 020 - right - 05-02 - none
# patient 020 - right - 06-03 - none
# patient 020 - right - 07-04 - none
# patient 021 - right - 02-01 - none
# patient 021 - right - 02-01 - mild
# patient 021 - right - 02-01 - moderate
# patient 021 - right - 03-01 - none
# patient 021 - right - 03-01 - mild
# patient 021 - right - 03-01 - moderate
# patient 021 - right - 04-01 - none
# patient 021 - right - 04-01 - mild
# patient 021 - right - 04-01 - moderate
# patient 021 - right - 05-02 - none
# patient 021 - right - 05-02 - mild
# patient 021 - right - 05-02 - moderate
# patient 021 - right - 06-03 - none
# patient 021 - right - 06-03 - mild
# patient 021 - right - 06-03 - moderate
# patient 021 - right - 07-04 - none
# patient 021 - right - 07-04 - mild
# patient 021 - right - 07-04 - moderate
# patient 021 - right - 08-07 - none
# patient 021 - right - 08-07 - mild
# patient 021 - right - 08-07 - moderate
# patient 022 - right - 02-01 - none
# patient 022 - right - 02-01 - mild
# patient 022 - right - 03-01 - none
# patient 022 - right - 03-01 - mild
# patient 022 - right - 04-01 - none
# patient 022 - right - 04-01 - mild
# patient 022 - right - 07-04 - none
# patient 022 - right - 07-04 - mild
# patient 023 - right - 06-03 - none
# patient 023 - right - 06-03 - mild
# patient 023 - right - 07-04 - none
# patient 023 - right - 07-04 - mild
# patient 102 - left - 06-03 - mild
# patient 102 - left - 06-03 - none
# patient 102 - left - 06-03 - moderate
# patient 103 - left - 06-03 - none
# patient 103 - left - 07-04 - none
# patient 103 - left - 08-07 - none
# patient 103 - right - 03-01 - none
# patient 103 - right - 06-03 - none
# patient 103 - right - 07-04 - none
# patient 105 - left - 05-02 - mild
# patient 105 - left - 06-03 - mild
# patient 105 - left - 07-04 - mild
# patient 105 - left - 08-06 - mild
# patient 105 - left - 08-07 - mild
# patient 105 - right - 02-01 - moderate
# patient 105 - right - 02-01 - none
# patient 105 - right - 02-01 - mild
# patient 105 - right - 03-01 - moderate
# patient 105 - right - 03-01 - none
# patient 105 - right - 03-01 - mild
# patient 105 - right - 04-01 - moderate
# patient 105 - right - 04-01 - none
# patient 105 - right - 04-01 - mild
# patient 105 - right - 07-04 - moderate
# patient 105 - right - 07-04 - none
# patient 105 - right - 07-04 - mild
# patient 108 - left - 05-02 - none
# patient 108 - left - 05-02 - mild
# patient 108 - left - 06-03 - none
# patient 108 - left - 06-03 - mild
# patient 108 - left - 07-04 - none
# patient 108 - left - 07-04 - mild
# patient 108 - left - 08-06 - none
# patient 108 - left - 08-06 - mild
# patient 108 - right - 06-03 - none
# patient 108 - right - 08-07 - none
# patient 109 - right - 02-01 - none
# patient 109 - right - 03-01 - none
# patient 109 - right - 04-01 - none
# patient 109 - right - 05-02 - none
# patient 109 - right - 06-03 - none
# patient 109 - right - 07-04 - none
# patient 109 - right - 08-05 - none
# patient 109 - right - 08-06 - none
# patient 109 - right - 08-07 - none
# patient 110 - left - 02-01 - none
# patient 110 - left - 02-01 - mild
# patient 110 - left - 02-01 - moderate
# patient 110 - left - 03-01 - none
# patient 110 - left - 03-01 - mild
# patient 110 - left - 03-01 - moderate
# patient 110 - left - 04-01 - none
# patient 110 - left - 04-01 - mild
# patient 110 - left - 04-01 - moderate
# patient 110 - left - 06-03 - none
# patient 110 - left - 06-03 - mild
# patient 110 - left - 06-03 - moderate
# patient 110 - left - 07-04 - none
# patient 110 - left - 07-04 - mild
# patient 110 - left - 07-04 - moderate

# %% [markdown]
# # 2. Load Channel and Severity-Wise Time-Frequency Activity

# %%
df_spectrogram       = pd.read_pickle(DATA_IO.path_events + "time_frequency_activity/LFP_TFA") 
df_spectrogram_LID   = df_spectrogram[df_spectrogram.severity!="none"]
df_spectrogram_noLID = df_spectrogram[df_spectrogram.severity=="none"]

# %% [markdown]
# # 3. Plot Spectrograms

# %%
# measure mean spectrograms
patient_onset_LID    = np.nanmean(list(df_spectrogram_LID[df_spectrogram_LID["onset_aligned_normalized"].apply(lambda x: isinstance(x, np.ndarray))].onset_aligned_normalized), axis=0)
patient_offset_LID   = np.nanmean(list(df_spectrogram_LID[df_spectrogram_LID["offset_aligned_normalized"].apply(lambda x: isinstance(x, np.ndarray))].offset_aligned_normalized), axis=0)
patient_onset_noLID  = np.nanmean(list(df_spectrogram_noLID[df_spectrogram_noLID["onset_aligned_normalized"].apply(lambda x: isinstance(x, np.ndarray))].onset_aligned_normalized), axis=0)
patient_offset_noLID = np.nanmean(list(df_spectrogram_noLID[df_spectrogram_noLID["offset_aligned_normalized"].apply(lambda x: isinstance(x, np.ndarray))].offset_aligned_normalized), axis=0)

# %%
plt      = utils_plotting.get_figure_template()
ax_noLID = plt.subplot2grid((80, 40), (0, 0) , colspan=10, rowspan=17)
ax_LID   = plt.subplot2grid((80, 40), (0, 12), colspan=10, rowspan=17)
ax_noLID = utils_plotting_spectrogram.plot_mean_spectrogram(patient_offset_noLID, group = "noLID", time_vector=np.linspace(-2,2,fs*4), 
                                                            vmin=-40, vmax=40, cmap="viridis", axis=ax_noLID)
ax_LID   = utils_plotting_spectrogram.plot_mean_spectrogram(patient_offset_LID, group = "LID", time_vector=np.linspace(-2,2,fs*4), 
                                                            vmin=-40, vmax=40, cmap="viridis", axis=ax_LID)
plt.savefig(DATA_IO.path_figure + "spectrogram/motor_stn_spectrogram.svg", dpi=1200)

# %% [markdown]
# # 4. Check Spectogram Pixel-Wise Significance

# %%
def contains_nan(matrix):
    return np.isnan(matrix).any()

spectrograms_LID   = np.array(df_spectrogram_LID[~df_spectrogram_LID['offset_aligned_normalized'].apply(contains_nan)].offset_aligned_normalized.to_list())
spectrograms_noLID = np.array(df_spectrogram_noLID[~df_spectrogram_noLID['offset_aligned_normalized'].apply(contains_nan)].offset_aligned_normalized.to_list())

# %% [markdown]
# ## 4.1 Compute Permutation Cluster Test

# %%
import mne
from mne.stats import permutation_cluster_test

# stack data along the first axis for permutation tests
data           = np.array([spectrograms_LID, spectrograms_noLID])  # list of arrays for each condition
adjacency      = mne.stats.combine_adjacency(87, 8192)
n_permutations = 1000  # number of permutations
# sun the cluster-based permutation test
F_stats, clusters, cluster_p_values, H0 = permutation_cluster_test(data, adjacency=adjacency)
# Out:
# Using a threshold of 3.893349
# stat_fun(H1): min=9.291075383476503e-12 max=48.426016736262476
# Running initial clustering …
# Found 218 clusters
#   0%|          | Permuting : 0/1023 [00:00<?,       ?it/s]

# %%
with open(DATA_IO.path_events+'time_frequency_activity/lfp_permutation_test_clustering/F_stats.npy', 'wb') as f:np.save(f, F_stats)
with open(DATA_IO.path_events+'time_frequency_activity/lfp_permutation_test_clustering/clusters.npy', 'wb') as f:np.save(f, clusters)
with open(DATA_IO.path_events+'time_frequency_activity/lfp_permutation_test_clustering/cluster_p_values.npy', 'wb') as f:np.save(f, cluster_p_values)

# %% [markdown]
# ## 4.2 Load Permutation Cluster Test Results

# %%
F_stats           = np.load(DATA_IO.path_events+'time_frequency_activity/lfp_permutation_test_clustering/F_stats.npy', allow_pickle=True)
clusters          = np.load(DATA_IO.path_events+'time_frequency_activity/lfp_permutation_test_clustering/clusters.npy', allow_pickle=True)
cluster_p_values  = np.load(DATA_IO.path_events+'time_frequency_activity/lfp_permutation_test_clustering/cluster_p_values.npy', allow_pickle=True)

# %% [markdown]
# ## 4.3 Plot F-Statistics

# %%
plt      = utils_plotting.get_figure_template()
ax_fstat = plt.subplot2grid((80, 40), (0, 0) , colspan=10, rowspan=17)
ax_cbar  = plt.subplot2grid((80, 40), (0, 15), colspan=10, rowspan=17)

ax_fstat, mesh = utils_plotting_spectrogram.plot_permutation_clusters_on_spectrogram(F_stats, clusters, cluster_p_values, alpha=0.05, 
                                                                                     time_vector=np.linspace(-2,2,fs*4), cmap="Reds", vmax=30, axis=ax_fstat)
cbar1 = plt.colorbar(mesh, ax=ax_cbar, orientation='vertical', fraction=0.05, pad=0.04)
cbar1.set_label("F-Statistics", fontsize=utils_plotting.LABEL_SIZE)

plt.savefig(DATA_IO.path_figure + "spectrogram/motor_stn_spectrogram_cluster_permutation.svg", dpi=1200)

# %% [markdown]
# # 5. Spectogram Mutual Information Analysis

# %%
df_spectrogram_LID["dyskinesia_group"]    = 1 # assign numeric value 1 to dyskinetic event
df_spectrogram_noLID["dyskinesia_group"]  = 0 # assign numeric value 0 to dyskinetic event

# concat two dataframes (no-LID and LID)
df_offset_aligned = pd.concat([df_spectrogram_LID[["offset_aligned_normalized","dyskinesia_group"]], 
                               df_spectrogram_noLID[["offset_aligned_normalized","dyskinesia_group"]]], 
                              ignore_index=True)

# rename the column
df_offset_aligned["spectrogram"] = df_offset_aligned["offset_aligned_normalized"]
df_offset_aligned                = df_offset_aligned[["spectrogram", "dyskinesia_group"]]
df_offset_aligned                = df_offset_aligned.dropna(subset=['spectrogram']) # removing nan spectrogram  

# downsample spectrograms with means to reduce time resolution for mutual information calculation
downsampled_spectrograms = []
for index,row in df_offset_aligned.iterrows():
    downsampled_spectrograms.append(utils_misc.spectrogram_downsampling_with_mean(row.spectrogram, fs=2048, time_interval_in_second=0.02)) # 20 ms. bins
    
df_offset_aligned["spectrogram"] = downsampled_spectrograms

n_rows = np.shape(df_offset_aligned.iloc[0].spectrogram)[0]
n_cols = np.shape(df_offset_aligned.iloc[0].spectrogram)[1]

print(str(n_rows) +  " x " + str(n_cols)) # time datapoints dropped from 8192 to 204
# Out:
# 87 x 204

# %% [markdown]
# Each spectrogram contains 87 frequency components (frequency resolution 1 from 4 to 90 Hz) and 204 (binned with 20 ms)
# time points equal to 4 seconds time period around event onset/offset [-2 seconds to +2 seconds]

# %% [markdown]
# ##  5.1 Measure Mutual Information and Significance

# %%
matrix_MI, matrix_MI_pvalues, matrix_bootstrap_max = utils_mutual_information.measure_spectrogram_mi(df_offset_aligned, n_iterations=100)
# Out:
# 4 Hz mutual information measurement started
# 5 Hz mutual information measurement started
# 6 Hz mutual information measurement started
# 7 Hz mutual information measurement started
# 8 Hz mutual information measurement started
# 9 Hz mutual information measurement started

# %% [markdown]
# ## 5.2. Save Measured MI and P-Values

# %%
with open(DATA_IO.path_events+'mutual_information/LFP/matrix_MI.npy', 'wb') as f: np.save(f, matrix_MI)
with open(DATA_IO.path_events+'mutual_information/LFP/matrix_MI_pvalues.npy', 'wb') as f: np.save(f, matrix_MI_pvalues)
with open(DATA_IO.path_events+'mutual_information/LFP/matrix_bootstrap_max.npy', 'wb') as f: np.save(f, matrix_bootsrap_max)

# %% [markdown]
# ## 5.3. Load Measured MI and P-Values

# %%
matrix_MI              = np.load(DATA_IO.path_events+'mutual_information/LFP/matrix_MI.npy')
matrix_MI_pvalues      = np.load(DATA_IO.path_events+'mutual_information/LFP/matrix_MI_pvalues.npy')
matrix_bootstrap_max   = np.load(DATA_IO.path_events+'mutual_information/LFP/matrix_bootstrap_max.npy')

# %%
significance_threshold = np.percentile(matrix_bootstrap_max.flatten(), 95)
MI_significant         = matrix_MI_pvalues>=significance_threshold

# %% [markdown]
# ## 5.4 Plot Time-Frequency MI

# %%
import matplotlib.colors as mcolors

plt     = utils_plotting.get_figure_template()
axis    = plt.subplot2grid((80, 40), (0, 0) , colspan=10, rowspan=17)
ax_cbar = plt.subplot2grid((80, 40), (0, 15), colspan=10, rowspan=17)

time_vector = np.linspace(-2,2,matrix_MI.shape[1])

freq_changed = []
for x in np.arange(4, 91):
    if((x>=35) and (x<60)):
        freq_changed.append(35+((x-35)/2.5))
    elif(x>=60):
        freq_changed.append(x-15)
    else:
        freq_changed.append(x)

cmap = plt.get_cmap("plasma")
norm = mcolors.Normalize(vmin=0, vmax=mult_comp_significance_threshold * 2)
low_color = cmap(norm(0)) 

mesh_1   = axis.pcolormesh(time_vector, freq_changed, matrix_MI, shading='auto', cmap="plasma", vmin=mult_comp_significance_threshold, vmax=0.26)
#axis.pcolormesh(time_vector, freq_changed, masked_matrix,shading='auto', cmap=mcolors.ListedColormap([low_color]),vmin=0, vmax=mult_comp_significance_threshold * 2)
axis.set_xticks([-2,-1,0,1,2], [-2,-1,0,1,2], fontsize =utils_plotting.LABEL_SIZE)
axis.set_yticks([4,12,20,35,45,55,65,75], [4,12,20,35,60,70,80,90], fontsize =utils_plotting.LABEL_SIZE)
axis.set_title("", fontsize=utils_plotting.LABEL_SIZE_title)

axis.spines.left.set_visible(False)
axis.spines.bottom.set_visible(False)
axis.spines.right.set_visible(False)
axis.spines.top.set_visible(False)
axis.xaxis.set_ticks_position('none')  # Hide the x-axis ticks
axis.yaxis.set_ticks_position('none')

mesh_1.set_clim(mult_comp_significance_threshold, 0.26)
cbar1 = plt.colorbar(mesh_1, ax=ax_cbar, orientation='vertical', fraction=0.05, pad=0.04)
custom_ticks = [0.14450718, 0.18300479, 0.22150239, 0.26]
cbar1.set_ticks(custom_ticks)
cbar1.set_ticklabels([f"{tick:.2f}" for tick in custom_ticks])

cbar1.set_label("Information [bits]", fontsize=utils_plotting.LABEL_SIZE)

plt.savefig("MI.png", dpi=1200)

# %%
mult_comp_significance_threshold
# Out:
# 0.1357287113148361
