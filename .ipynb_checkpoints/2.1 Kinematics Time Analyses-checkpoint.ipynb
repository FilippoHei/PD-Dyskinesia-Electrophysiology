# %%
# Import public packages and functions
import os
import pandas as pd
import numpy as np
import sys
import json
from pathlib import Path

import seaborn as sns
import matplotlib.pyplot as plt
import scikit_posthocs as sp

# inserting the lib folder to the compiler
sys.path.insert(0, './lib')
sys.path.insert(0, './utils/')

import utils_plotting
import utils_accelerometer

from lib_event import KINEMATIC_DATA 
from lib_data import DATA_IO
from lib_statistics import NON_PARAMETRIC_TEST

# %%
PATH_CURR  = os.path.abspath(os.curdir)    # current code
PATH       = (str(Path(PATH_CURR).parent)) # data repository: upper directory where datasets situated
SUB        = '016'

# %%
# 1. Load event history of patient
df_events_016 = pd.read_csv(DATA_IO.path_events_dataframe + "SUB_"+ SUB +"_EVENTS.csv")

# 2. load accelerometer data
kinematic_016 = KINEMATIC_DATA(PATH, SUB)
# Out:
# ... pickle loading: C:\Users\a.kaymak\Desktop\Papers\2025 Parkinson Dyskinesia LFP-ECG\files\data\sub-016\016_mergedData_v4.0_acc_right.P
# ... pickle loading: C:\Users\a.kaymak\Desktop\Papers\2025 Parkinson Dyskinesia LFP-ECG\files\data\sub-016\016_mergedData_v4.0_acc_left.P

# %%
acc_events = utils_accelerometer.create_accelerometer_event_dictionary(df_events_016, kinematic_016, kinematic_016.fs, t_observation=4)
colors     = utils_plotting.colors

# %% [markdown]
# # 1. Plot Event Categories

# %%
utils_plotting.plot_accelerometer_events_by_category(acc_events,
                                                     kinematic_016,
                                                     colors = colors, 
                                                     figure_name = DATA_IO.path_figure +"SUB" + str(SUB) +"_events")

# %% [markdown]
# ## 1.1 Voluntary Tapping

# %%
utils_plotting.plot_accelerometer_events_by_dyskinesia(acc_events,
                                                       kinematic_016,
                                                       event_category ="voluntary_tapping", 
                                                       colors = colors, 
                                                       figure_name = DATA_IO.path_figure +"SUB" + str(SUB) +"_event_voluntary_tapping")

# %%
utils_plotting.plot_accelerometer_events_by_dyskinesia(acc_events,
                                                       kinematic_016,
                                                       event_category ="involuntary_tapping", 
                                                       colors = colors, 
                                                       figure_name = DATA_IO.path_figure +"SUB" + str(SUB) +"_event_involuntary_tapping")

# %%
utils_plotting.plot_accelerometer_events_by_dyskinesia(acc_events,
                                                       kinematic_016,
                                                       event_category ="involuntary_movement", 
                                                       colors = colors, 
                                                       figure_name = DATA_IO.path_figure +"SUB" + str(SUB) +"_event_involuntary_movement")

# %% [markdown]
# # 2. Extract Temporal Metrics for Event Segments

# %%
df_acc_metrics_016, features_temporal = kinematic_016.extract_temporal_metrics_from_event_segments(patient=SUB, event_dataframe=df_events_016)

# %%
kw_test = NON_PARAMETRIC_TEST.kruskall_wallis(df_acc_metrics_016, group_variable="event_category", feature_set=features_temporal)
kw_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 kw_test = NON_PARAMETRIC_TEST.kruskall_wallis(df_acc_metrics_016, group_variable="event_category", feature_set=features_temporal)
#       2 kw_test
#
# File ~\Desktop\Papers\2025 Parkinson Dyskinesia LFP-ECG\files\PD-Dyskinesia-Electrophysiology\./lib\lib_statistics.py:20, in NON_PARAMETRIC_TEST.kruskall_wallis(dataset, group_variable, feature_set)
#      17     p_uncorrected.append(p)
#      19 # correct p-values with Holm-Bonferroni correction
# ---> 20 p_corrected = pg.multicomp(pvals=p_values, method='holm')[1]
#      22 # store feature and corresponding corrected p-values in dataframe
#      23 kw_results = pd.DataFrame(columns=["feature", "pvalue"])
#
# NameError: name 'p_values' is not defined
