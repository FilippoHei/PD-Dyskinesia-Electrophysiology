# %%
# Import public packages and functions
import os
import pandas as pd
import numpy as np
import sys
import json
from pathlib import Path

import seaborn as sns
import matplotlib.pyplot as plt
import scikit_posthocs as sp

# inserting the lib folder to the compiler
sys.path.insert(0, './lib')
sys.path.insert(0, './utils/')

import utils_plotting_accelerometer
import utils_accelerometer

from lib_accelerometer import ACCELEROMETER 
from lib_data import DATA_IO
from lib_statistics import NON_PARAMETRIC_TEST

# %%
PATH_CURR  = os.path.abspath(os.curdir)    # current code
PATH       = (str(Path(PATH_CURR).parent)) # data repository: upper directory where datasets situated
SUB        = '016'

# %%
# 1. Load event history of patient
df_events_016 = pd.read_csv(DATA_IO.path_events_dataframe + "SUB_"+ SUB +"_EVENTS_ACC.csv")
# 2. load accelerometer data
acc_016       = ACCELEROMETER(PATH, SUB)
# Out:
# ... pickle loading: C:\Users\a.kaymak\Desktop\Papers\2025 Parkinson Dyskinesia LFP-ECG\files\data\sub-016\016_mergedData_v4.0_acc_right.P
# ... pickle loading: C:\Users\a.kaymak\Desktop\Papers\2025 Parkinson Dyskinesia LFP-ECG\files\data\sub-016\016_mergedData_v4.0_acc_left.P

# %%
acc_events = utils_accelerometer.create_accelerometer_event_dictionary(df_events_016, acc_016, acc_016.fs, t_observation=4)
colors     = utils_plotting_accelerometer.colors

# %% [markdown]
# # 1. Plot Event Categories

# %%
utils_plotting_accelerometer.plot_accelerometer_events_by_category(acc_events, acc_016, colors = colors, 
                                                                   figure_name = DATA_IO.path_figure +"SUB" + str(SUB) +"accelerometer_events")

# %% [markdown]
# ## 1.1 Voluntary Tapping

# %%
utils_plotting_accelerometer.plot_accelerometer_events_by_dyskinesia(acc_events, acc_016, colors = colors, 
                                                                     figure_name = DATA_IO.path_figure +"SUB" + str(SUB) +"accelerometer_events_per_dyskinesia_severity")

# %% [markdown]
# # 2. Extract Temporal Metrics for Event Segments

# %%
df_acc_metrics_016, features_temporal = acc_016.extract_temporal_metrics_from_event_segments(patient=SUB, event_dataframe=df_events_016)

# %% [markdown]
# ## 2.1 Comparison Between Tappping vs Involuntary Movements

# %%
kw_test   = NON_PARAMETRIC_TEST.kruskall_wallis(df_acc_metrics_016, group_variable="event_category", 
                                                feature_set=features_temporal, subset_variable="event_segment")

dunn_test = NON_PARAMETRIC_TEST.dunn_test(df_acc_metrics_016, group_variable="event_category", 
                                          feature_set=features_temporal, subset_variable="event_segment")

# %% [markdown]
# ## 2.2 Comparison for Tapping Between Different Dyskinesia Severity Scores

# %%
kw_test_tapping   = NON_PARAMETRIC_TEST.kruskall_wallis(df_acc_metrics_016[df_acc_metrics_016.event_category=="tapping"], 
                                                        group_variable="dyskinesia_severity", 
                                                        feature_set=features_temporal, subset_variable="event_segment")

dunn_test_tapping = NON_PARAMETRIC_TEST.dunn_test(df_acc_metrics_016[df_acc_metrics_016.event_category=="tapping"], 
                                                  group_variable="dyskinesia_severity", 
                                                  feature_set=features_temporal, subset_variable="event_segment")

# %%
dunn_test_tapping[dunn_test_tapping.pvalue<=0.05]
# Out:
#    event_segment             feature    group1    group2    pvalue
# 6            pre               range  LID_mild  LID_none  0.027584
# 7            pre               range  LID_none  LID_mild  0.027584
# 16           pre  mean_crossing_rate  LID_mild  LID_none  0.024312
# 17           pre  mean_crossing_rate  LID_none  LID_mild  0.024312
# 40         event                 iqr  LID_mild  LID_none  0.045524
# 41         event                 iqr  LID_none  LID_mild  0.045524
# 46         event  mean_crossing_rate  LID_mild  LID_none  0.034677
# 47         event  mean_crossing_rate  LID_none  LID_mild  0.034677

# %% [markdown]
# ## 2.3 Comparison for Involuntary Movement Between Different Dyskinesia Severity Scores

# %%
kw_test_involuntary_move = NON_PARAMETRIC_TEST.kruskall_wallis(df_acc_metrics_016[df_acc_metrics_016.event_category=="involuntary_movement"], 
                                                               group_variable="dyskinesia_severity", 
                                                               feature_set=features_temporal, subset_variable="event_segment")

dunn_test_involuntary_move = NON_PARAMETRIC_TEST.dunn_test(df_acc_metrics_016[df_acc_metrics_016.event_category=="involuntary_movement"], 
                                                           group_variable="dyskinesia_severity", 
                                                           feature_set=features_temporal, subset_variable="event_segment")

# %%
dunn_test_involuntary_move[dunn_test_involuntary_move.pvalue<=0.05]
# Out:
# Empty DataFrame
# Columns: [event_segment, feature, group1, group2, pvalue]
# Index: []
