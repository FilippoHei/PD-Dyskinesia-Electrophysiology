# %%
import warnings
warnings.filterwarnings("ignore")

# Import public packages and functions
import os
import pandas as pd
import numpy as np
import sys
import json
from pathlib import Path

import seaborn as sns
import matplotlib.pyplot as plt
import scikit_posthocs as sp

# inserting the lib folder to the compiler
sys.path.insert(0, './lib')
sys.path.insert(0, './utils/')

#import utils scripts
import utils_accelerometer, utils_misc, utils_psd, utils_plotting_psd

from lib_LFP import LFP
from lib_event import EVENTS
from lib_data import DATA_IO

# %% [markdown]
# # 1. Data Load

# %%
PATH_CURR  = os.path.abspath(os.curdir)    # current code
PATH       = (str(Path(PATH_CURR).parent)) # data repository: upper directory where datasets situated
SUB        = '016'

# 1. Load event history of patient
df_lfp_events = pd.read_pickle(DATA_IO.path_events_dataframe + "SUB_"+ SUB +"_EVENTS_LFP_RECORDINGS.pkl")
df_lfp_events.LFP_channel = df_lfp_events.LFP_channel.apply(str)

# %%
rec       = df_lfp_events.iloc[2000].event_recording
freq, psd = utils_psd.measure_normalized_psd(rec, fs=2048)

# %%
plt.plot(freq, psd)
freq
# Out:
# array([  4. ,   4.5,   5. ,   5.5,   6. ,   6.5,   7. ,   7.5,   8. ,
#          8.5,   9. ,   9.5,  10. ,  10.5,  11. ,  11.5,  12. ,  12.5,
#         13. ,  13.5,  14. ,  14.5,  15. ,  15.5,  16. ,  16.5,  17. ,
#         17.5,  18. ,  18.5,  19. ,  19.5,  20. ,  20.5,  21. ,  21.5,
#         22. ,  22.5,  23. ,  23.5,  24. ,  24.5,  25. ,  25.5,  26. ,
#         26.5,  27. ,  27.5,  28. ,  28.5,  29. ,  29.5,  30. ,  30.5,
#         31. ,  31.5,  32. ,  32.5,  33. ,  33.5,  34. ,  34.5,  35. ,
#         35.5,  36. ,  36.5,  37. ,  37.5,  38. ,  38.5,  39. ,  39.5,
#         40. ,  40.5,  41. ,  41.5,  42. ,  42.5,  43. ,  43.5,  44. ,
#         44.5,  45. ,  45.5,  46. ,  46.5,  47. ,  47.5,  48. ,  48.5,
#         49. ,  49.5,  50. ,  50.5,  51. ,  51.5,  52. ,  52.5,  53. ,
#         53.5,  54. ,  54.5,  55. ,  55.5,  56. ,  56.5,  57. ,  57.5,
#         58. ,  58.5,  59. ,  59.5,  60. ,  60.5,  61. ,  61.5,  62. ,
# ...

# %%
# Import the FOOOF object
from fooof import FOOOF

# Initialize FOOOF object
fm = FOOOF()

# Define frequency range across which to model the spectrum
freq_range = [5, 95]

# Model the power spectrum with FOOOF, and print out a report

# %%
fm.fit(freq, psd)
# Out:
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.

# %% [markdown]
# # 2. Normalized PSD Plots

# %% [markdown]
# ## 2.1 Average PSD for Event Segment without Hemisphere Separation

# %% [markdown]
# ### 2.1.1 Involuntary Movements

# %%
utils_plotting_psd.plot_LFP_PSD_for_event_category(df_lfp_events, event_category="involuntary_movement", segment="event")
utils_plotting_psd.plot_LFP_PSD_for_event_category_and_segment(df_lfp_events, event_category="involuntary_movement")

# %% [markdown]
# ### 2.1.2 Tapping

# %%
utils_plotting_psd.plot_LFP_PSD_for_event_category(df_lfp_events, event_category="tapping", segment="event")
utils_plotting_psd.plot_LFP_PSD_for_event_category_and_segment(df_lfp_events, event_category="tapping")

# %% [markdown]
# ## 2.2 Average PSD for Event Segment with Hemisphere Separation

# %% [markdown]
# ### 2.2.1 Involuntary Movements

# %%
print("RIGHT HEMISPHERE ---------------------------------------------------")
utils_plotting_psd.plot_LFP_PSD_for_hemisphere_and_event_category(df_lfp_events, hemisphere="right", event_category="involuntary_movement", segment="event")
print("LEFT HEMISPHERE ----------------------------------------------------")
utils_plotting_psd.plot_LFP_PSD_for_hemisphere_and_event_category(df_lfp_events, hemisphere="left", event_category="involuntary_movement", segment="event")
# Out:
# RIGHT HEMISPHERE ---------------------------------------------------
# LEFT HEMISPHERE ----------------------------------------------------

# %% [markdown]
# ### 2.2.2 Tapping

# %%
print("RIGHT HEMISPHERE ---------------------------------------------------")
utils_plotting_psd.plot_LFP_PSD_for_hemisphere_and_event_category(df_lfp_events, hemisphere="right", event_category="tapping", segment="event")
print("LEFT HEMISPHERE ----------------------------------------------------")
utils_plotting_psd.plot_LFP_PSD_for_hemisphere_and_event_category(df_lfp_events, hemisphere="left", event_category="tapping", segment="event")
# Out:
# RIGHT HEMISPHERE ---------------------------------------------------
# LEFT HEMISPHERE ----------------------------------------------------
