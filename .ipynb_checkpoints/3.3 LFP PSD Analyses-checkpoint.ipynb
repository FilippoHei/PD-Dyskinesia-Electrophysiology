# %%
# Import public packages and functions
import os
import pandas as pd
import numpy as np
import sys
import json
from pathlib import Path

import seaborn as sns
import matplotlib.pyplot as plt
import scikit_posthocs as sp

import warnings
warnings.filterwarnings("ignore")

# inserting the lib folder to the compiler
sys.path.insert(0, './lib')
sys.path.insert(0, './utils/')

import utils_plotting_psd, utils_plotting, utils_psd

from lib_data import DATA_IO

# %%
PATH_CURR = os.path.abspath(os.curdir)    # current code
PATH      = (str(Path(PATH_CURR).parent)) # data repository: upper directory where datasets situated

# %% [markdown]
# # 1. STN Controlateral Motor Region LFP-PSD for Tapping Events

# %%
PSD_TAPPING_C_MOTOR_LID   = pd.read_pickle(DATA_IO.path_events + "psd/LFP/CONTROLATERAL_MOTOR_LID.pkl")
PSD_TAPPING_C_MOTOR_noLID = pd.read_pickle(DATA_IO.path_events + "psd/LFP/CONTROLATERAL_MOTOR_noLID.pkl")

# %% [markdown]
# ## 1.1 LID vd no-LID

# %%
utils_plotting_psd.plot_LID_vs_noLID_psd(dataset_LID=PSD_TAPPING_C_MOTOR_LID, dataset_noLID=PSD_TAPPING_C_MOTOR_noLID, segment="pre_event", 
                                         figure_name=DATA_IO.path_figure + "LFP-PSD/tapping/controlateral/motor_LID_vs_noLID_for_pre_event_segment")

# %%
utils_plotting_psd.plot_LID_vs_noLID_psd(dataset_LID=PSD_TAPPING_C_MOTOR_LID, dataset_noLID=PSD_TAPPING_C_MOTOR_noLID, segment="event", 
                                         figure_name=DATA_IO.path_figure + "LFP-PSD/tapping/controlateral/motor_LID_vs_noLID_for_event_segment")

# %%
utils_plotting_psd.plot_LID_vs_noLID_psd(dataset_LID=PSD_TAPPING_C_MOTOR_LID, dataset_noLID=PSD_TAPPING_C_MOTOR_noLID, segment="post_event", 
                                         figure_name=DATA_IO.path_figure + "LFP-PSD/tapping/controlateral/motor_LID_vs_noLID_for_post_event_segment")

# %% [markdown]
# ## 1.2 LID Arm Severity

# %%
utils_plotting_psd.plot_LID_severity_psd(PSD_TAPPING_C_MOTOR_LID, segment="pre_event", dyskinesia_strategy="dyskinesia_arm", error_type="se", 
                                         figure_name=DATA_IO.path_figure + "LFP-PSD/tapping/controlateral/motor_LID_arm_severity_for_pre_event_segment")

# %%
utils_plotting_psd.plot_LID_severity_psd(PSD_TAPPING_C_MOTOR_LID, segment="event", dyskinesia_strategy="dyskinesia_arm", error_type="se", 
                                         figure_name=DATA_IO.path_figure + "LFP-PSD/tapping/controlateral/motor_LID_arm_severity_for_event_segment")

# %%
utils_plotting_psd.plot_LID_severity_psd(PSD_TAPPING_C_MOTOR_LID, segment="post_event", dyskinesia_strategy="dyskinesia_arm", error_type="se", 
                                         figure_name=DATA_IO.path_figure + "LFP-PSD/tapping/controlateral/motor_LID_arm_severity_for_post_event_segment")

# %% [markdown]
# ## 1.3 LID Total Severity

# %%
utils_plotting_psd.plot_LID_severity_psd(PSD_TAPPING_C_MOTOR_LID, segment="pre_event", dyskinesia_strategy="dyskinesia_total", error_type="se", 
                                         figure_name=DATA_IO.path_figure + "LFP-PSD/tapping/controlateral/motor_LID_total_severity_for_pre_event_segment")

# %%
utils_plotting_psd.plot_LID_severity_psd(PSD_TAPPING_C_MOTOR_LID, segment="event", dyskinesia_strategy="dyskinesia_total", error_type="se", 
                                         figure_name=DATA_IO.path_figure + "LFP-PSD/tapping/controlateral/motor_LID_total_severity_for_event_segment")

# %%
utils_plotting_psd.plot_LID_severity_psd(PSD_TAPPING_C_MOTOR_LID, segment="post_event", dyskinesia_strategy="dyskinesia_total", error_type="se", 
                                         figure_name=DATA_IO.path_figure + "LFP-PSD/tapping/controlateral/motor_LID_total_severity_for_post_event_segment")

# %% [markdown]
# ## 1.4 no-LID (<30) vs no-LID (>=30)

# %%
utils_plotting_psd.plot_noLID_states_psd(PSD_TAPPING_C_MOTOR_noLID, segment="pre_event", error_type="se", 
                                         figure_name=DATA_IO.path_figure + "LFP-PSD/tapping/controlateral/motor_noLID_states_for_pre_event_segment")

# %%
utils_plotting_psd.plot_noLID_states_psd(PSD_TAPPING_C_MOTOR_noLID, segment="event", error_type="se", 
                                         figure_name=DATA_IO.path_figure + "LFP-PSD/tapping/controlateral/motor_noLID_states_for_event_segment")

# %%
utils_plotting_psd.plot_noLID_states_psd(PSD_TAPPING_C_MOTOR_noLID, segment="post_event", error_type="se", 
                                         figure_name=DATA_IO.path_figure + "LFP-PSD/tapping/controlateral/motor_noLID_states_for_post_event_segment")

# %% [markdown]
# # 2. Change of Controlateral Event LFP-PSD as Function of Time

# %%
feature = "event_gamma_mean"

# %%
sns.scatterplot(PSD_TAPPING_C_MOTOR_LID[PSD_TAPPING_C_MOTOR_LID.dyskinesia_arm == "mild"], x='event_start_time', 
                y=feature, color=utils_plotting.colors["voluntary"]["mild"])
sns.scatterplot(PSD_TAPPING_C_MOTOR_LID[PSD_TAPPING_C_MOTOR_LID.dyskinesia_arm == "moderate"], x='event_start_time', 
                y=feature, color=utils_plotting.colors["voluntary"]["moderate"])
sns.scatterplot(PSD_TAPPING_C_MOTOR_LID[PSD_TAPPING_C_MOTOR_LID.dyskinesia_arm == "severe"], x='event_start_time', 
                y=feature, color=utils_plotting.colors["voluntary"]["severe"])
plt.ylim([-100,200])
# Out:
# (-100.0, 200.0)

# %%
PSD_TAPPING_C_MOTOR_LID[PSD_TAPPING_C_MOTOR_LID.dyskinesia_arm == "moderate"].patient.unique()
# Out:
# array(['012', '020', '102', '105'], dtype=object)
