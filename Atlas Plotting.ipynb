# %%
# Import public packages and functions
import os
import pandas as pd
import numpy as np
import sys
import json
from pathlib import Path
from scipy import signal

import seaborn as sns
import matplotlib.pyplot as plt
import scikit_posthocs as sp

import warnings
warnings.filterwarnings("ignore")

# inserting the lib folder to the compiler
sys.path.insert(0, './lib')
sys.path.insert(0, './utils/')

import utils_io, utils_coherence

from lib_data import DATA_IO

# %%
import nilearn.plotting as plotting
from nilearn import datasets
from nilearn.image import index_img

# Fetch DiSTAL or another atlas (e.g., DiFuMo)
atlas = datasets.fetch_atlas_difumo(dimension=64)  # Example using DiFuMo atlas
atlas_filename = atlas.maps

# Plotting the subthalamic nucleus (STN) and cortex
# You need to identify the appropriate index for STN and cortex from the atlas
stn_index = 0  # Replace with actual index for STN
cortex_index = 1  # Replace with actual index for cortex

# Extracting and plotting the regions
stn_img = index_img(atlas_filename, stn_index)
cortex_img = index_img(atlas_filename, cortex_index)

# Plotting using nilearn's plotting functions
plotting.plot_stat_map(stn_img, title="Subthalamic Nucleus (STN)")
plotting.plot_stat_map(cortex_img, title="Cortex")
plotting.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import nilearn.plotting as plotting
#       2 from nilearn import datasets
#       3 from nilearn.image import index_img
#
# File ~\Anaconda3\lib\site-packages\nilearn\plotting\__init__.py:59
#      57 ###############################################################################
#      58 from . import cm
# ---> 59 from .find_cuts import (
#      60     find_cut_slices,
#      61     find_parcellation_cut_coords,
#      62     find_probabilistic_atlas_cut_coords,
#      63     find_xyz_cut_coords,
#      64 )
#      65 from .html_connectome import view_connectome, view_markers
#      66 from .html_stat_map import view_img
#
# File ~\Anaconda3\lib\site-packages\nilearn\plotting\find_cuts.py:11
#       8 import numpy as np
#       9 from scipy.ndimage import center_of_mass, find_objects, label
# ...
